# %%
from platform import python_version

print(python_version())
# Out:
# 3.10.9

# %%
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

import os

import haversine as hs

from datetime import datetime, timedelta

# %%
from IPython.display import display

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
datapath = "f1db_csv/"

# %%
os.listdir(datapath)
# Out:
# ['circuits.csv',
#  'status.csv',
#  'lap_times.csv',
#  'sprint_results.csv',
#  'drivers.csv',
#  'races.csv',
#  'constructors.csv',
#  'constructor_standings.csv',
#  'qualifying.csv',
#  'driver_standings.csv',
#  'constructor_results.csv',
#  'pit_stops.csv',
#  'seasons.csv',
#  'results.csv']

# %%
for file in list(os.listdir(datapath)):
    print(file)
# Out:
# circuits.csv
# status.csv
# lap_times.csv
# sprint_results.csv
# drivers.csv
# races.csv
# constructors.csv
# constructor_standings.csv
# qualifying.csv
# driver_standings.csv
# constructor_results.csv
# pit_stops.csv
# seasons.csv
# results.csv

# %%
filename = "circuits.csv"

circuits = pd.read_csv(datapath+filename)

circuits.shape
# Out:
# (77, 9)

# %%
circuits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   circuitId   77 non-null     int64
#  1   circuitRef  77 non-null     object
#  2   name        77 non-null     object
#  3   location    77 non-null     object
#  4   country     77 non-null     object
#  5   lat         77 non-null     float64
#  6   lng         77 non-null     float64
#  7   alt         77 non-null     object
#  8   url         77 non-null     object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 5.5+ KB

# %%
circuits
# Out:
#     circuitId      circuitRef                                   name  \
# 0           1     albert_park         Albert Park Grand Prix Circuit
# 1           2          sepang           Sepang International Circuit
# 2           3         bahrain          Bahrain International Circuit
# 3           4       catalunya         Circuit de Barcelona-Catalunya
# 4           5        istanbul                          Istanbul Park
# 5           6          monaco                      Circuit de Monaco
# 6           7      villeneuve              Circuit Gilles Villeneuve
# 7           8     magny_cours          Circuit de Nevers Magny-Cours
# 8           9     silverstone                    Silverstone Circuit
# 9          10  hockenheimring                         Hockenheimring
# 10         11     hungaroring                            Hungaroring
# 11         12        valencia                Valencia Street Circuit
# 12         13             spa           Circuit de Spa-Francorchamps
# ...

# %%
circuits.sample(5)
# Out:
#     circuitId circuitRef                     name              location  \
# 30         31  donington           Donington Park      Castle Donington
# 57         58    aintree                  Aintree             Liverpool
# 68         69   americas  Circuit of the Americas                Austin
# 4           5   istanbul            Istanbul Park              Istanbul
# 25         26      jerez        Circuito de Jerez  Jerez de la Frontera
#
#    country      lat       lng  alt  \
# 30      UK  52.8306  -1.37528   88
# 57      UK  53.4769  -2.94056   20
# 68     USA  30.1328 -97.64110  161
# 4   Turkey  40.9517  29.40500  130
# 25   Spain  36.7083  -6.03417   37
#
#                                                           url
# 30                http://en.wikipedia.org/wiki/Donington_Park
# 57  http://en.wikipedia.org/wiki/Aintree_Motor_Racing_Circuit
# 68       http://en.wikipedia.org/wiki/Circuit_of_the_Americas
# 4                  http://en.wikipedia.org/wiki/Istanbul_Park
# ...

# %%
cols = circuits.columns.tolist()

print(cols)
# Out:
# ['circuitId', 'circuitRef', 'name', 'location', 'country', 'lat', 'lng', 'alt', 'url']

# %%
cols = ['circuitId', 'circuitRef', 'name', 'location', 'country', 'lat', 'lng']

circuits = circuits[cols]

circuits.sample(10)
# Out:
#     circuitId      circuitRef                                name  \
# 72         75        portimao  Autódromo Internacional do Algarve
# 27         28         okayama       Okayama International Circuit
# 1           2          sepang        Sepang International Circuit
# 31         32       rodriguez        Autódromo Hermanos Rodríguez
# 68         69        americas             Circuit of the Americas
# 5           6          monaco                   Circuit de Monaco
# 74         77          jeddah             Jeddah Corniche Circuit
# 18         19    indianapolis         Indianapolis Motor Speedway
# 70         71           sochi                      Sochi Autodrom
# 9          10  hockenheimring                      Hockenheimring
#
#         location       country       lat        lng
# 72      Portimão      Portugal  37.22700   -8.62670
# 27       Okayama         Japan  34.91500  134.22100
# 1   Kuala Lumpur      Malaysia   2.76083  101.73800
# ...

# %%
circuits['country'].value_counts()
# Out:
# USA              11
# France            7
# Spain             6
# Portugal          4
# UK                4
# Italy             4
# Japan             3
# Canada            3
# Germany           3
# Belgium           3
# Austria           2
# South Africa      2
# Brazil            2
# Australia         2
# Singapore         1
# Netherlands       1
# Saudi Arabia      1
# Azerbaijan        1
# Russia            1
# India             1
# Switzerland       1
# Morocco           1
# Bahrain           1
# Sweden            1
# Korea             1
# China             1
# Mexico            1
# Turkey            1
# Monaco            1
# Argentina         1
# UAE               1
# United States     1
# Malaysia          1
# Hungary           1
# Qatar             1
# Name: country, dtype: int64

# %%
filename = 'races.csv'

races = pd.read_csv(datapath+filename)

races.shape
# Out:
# (1101, 18)

# %%
races.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1101 entries, 0 to 1100
# Data columns (total 18 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   raceId       1101 non-null   int64
#  1   year         1101 non-null   int64
#  2   round        1101 non-null   int64
#  3   circuitId    1101 non-null   int64
#  4   name         1101 non-null   object
#  5   date         1101 non-null   object
#  6   time         1101 non-null   object
#  7   url          1101 non-null   object
#  8   fp1_date     1101 non-null   object
#  9   fp1_time     1101 non-null   object
#  10  fp2_date     1101 non-null   object
#  11  fp2_time     1101 non-null   object
#  12  fp3_date     1101 non-null   object
#  13  fp3_time     1101 non-null   object
#  14  quali_date   1101 non-null   object
#  15  quali_time   1101 non-null   object
#  16  sprint_date  1101 non-null   object
#  17  sprint_time  1101 non-null   object
# dtypes: int64(4), object(14)
# ...

# %%
races.sample(5)
# Out:
#       raceId  year  round  circuitId                  name        date  \
# 816      817  1952      1         66      Swiss Grand Prix  1952-05-18
# 474      475  1982      9         39      Dutch Grand Prix  1982-07-03
# 76        77  2005      7         20   European Grand Prix  2005-05-29
# 950      963  2016     16          2  Malaysian Grand Prix  2016-10-02
# 1012    1025  2019     16         71    Russian Grand Prix  2019-09-29
#
#           time                                                     url  \
# 816         \N      http://en.wikipedia.org/wiki/1952_Swiss_Grand_Prix
# 474         \N      http://en.wikipedia.org/wiki/1982_Dutch_Grand_Prix
# 76    14:00:00   http://en.wikipedia.org/wiki/2005_European_Grand_Prix
# 950   07:00:00  http://en.wikipedia.org/wiki/2016_Malaysian_Grand_Prix
# 1012  11:10:00    http://en.wikipedia.org/wiki/2019_Russian_Grand_Prix
#
#      fp1_date fp1_time fp2_date fp2_time fp3_date fp3_time quali_date  \
# ...

# %%
races.sort_values(by=['year', 'round'], ascending=[False, True], inplace=True)

races.head(50)
# Out:
#       raceId  year  round  circuitId                       name        date  \
# 1079    1098  2023      1          3         Bahrain Grand Prix  2023-03-05
# 1080    1099  2023      2         77   Saudi Arabian Grand Prix  2023-03-19
# 1081    1100  2023      3          1      Australian Grand Prix  2023-04-02
# 1082    1101  2023      4         73      Azerbaijan Grand Prix  2023-04-30
# 1083    1102  2023      5         79           Miami Grand Prix  2023-05-07
# 1084    1104  2023      6          6          Monaco Grand Prix  2023-05-28
# 1085    1105  2023      7          4         Spanish Grand Prix  2023-06-04
# 1086    1106  2023      8          7        Canadian Grand Prix  2023-06-18
# 1087    1107  2023      9         70        Austrian Grand Prix  2023-07-02
# 1088    1108  2023     10          9         British Grand Prix  2023-07-09
# 1089    1109  2023     11         11       Hungarian Grand Prix  2023-07-23
# ...

# %%
races.loc[races['name'] == 'Indianapolis 500']
# Out:
#      raceId  year  round  circuitId              name        date time  \
# 747     748  1960      3         19  Indianapolis 500  1960-05-30   \N
# 756     757  1959      2         19  Indianapolis 500  1959-05-30   \N
# 767     768  1958      4         19  Indianapolis 500  1958-05-30   \N
# 777     778  1957      3         19  Indianapolis 500  1957-05-30   \N
# 785     786  1956      3         19  Indianapolis 500  1956-05-30   \N
# 793     794  1955      3         19  Indianapolis 500  1955-05-30   \N
# 799     800  1954      2         19  Indianapolis 500  1954-05-31   \N
# 808     809  1953      2         19  Indianapolis 500  1953-05-30   \N
# 817     818  1952      2         19  Indianapolis 500  1952-05-30   \N
# 825     826  1951      2         19  Indianapolis 500  1951-05-30   \N
# 834     835  1950      3         19  Indianapolis 500  1950-05-30   \N
#
#                                                     url fp1_date fp1_time  \
# ...

# %%
races.drop(races[races['name'] == 'Indianapolis 500'].index, inplace = True)

# %%
cols = races.columns.tolist()

for col in cols:
    print(col)
# Out:
# raceId
# year
# round
# circuitId
# name
# date
# time
# url
# fp1_date
# fp1_time
# fp2_date
# fp2_time
# fp3_date
# fp3_time
# quali_date
# quali_time
# sprint_date
# sprint_time

# %%
cols = ['raceId', 'year', 'round', 'circuitId', 'name', 'date', 'time']

races = races[cols]

races.sample(10)
# Out:
#       raceId  year  round  circuitId                      name        date  \
# 933      944  2015     18         18      Brazilian Grand Prix  2015-11-15
# 657      658  1969      3          6         Monaco Grand Prix  1969-05-18
# 525      526  1979     15         46  United States Grand Prix  1979-10-07
# 109      110  2003      3         18      Brazilian Grand Prix  2003-04-06
# 253      254  1995     15         28        Pacific Grand Prix  1995-10-22
# 979      992  2018      4         73     Azerbaijan Grand Prix  2018-04-29
# 338      339  2010      3          2      Malaysian Grand Prix  2010-04-04
# 415      416  1986     13         14        Italian Grand Prix  1986-09-07
# 1049    1064  2021     13         39          Dutch Grand Prix  2021-09-05
# 1070    1087  2022     14         13        Belgian Grand Prix  2022-08-28
#
#           time
# 933   16:00:00
# 657         \N
# 525         \N
# 109         \N
# 253         \N
# 979   12:10:00
# 338   08:00:00
# ...

# %%
races.head()
# Out:
#       raceId  year  round  circuitId                      name        date  \
# 1079    1098  2023      1          3        Bahrain Grand Prix  2023-03-05
# 1080    1099  2023      2         77  Saudi Arabian Grand Prix  2023-03-19
# 1081    1100  2023      3          1     Australian Grand Prix  2023-04-02
# 1082    1101  2023      4         73     Azerbaijan Grand Prix  2023-04-30
# 1083    1102  2023      5         79          Miami Grand Prix  2023-05-07
#
#           time
# 1079  15:00:00
# 1080  17:00:00
# 1081  05:00:00
# 1082  11:00:00
# 1083  19:30:00

# %%
circuits.head()
# Out:
#    circuitId   circuitRef                            name      location  \
# 0          1  albert_park  Albert Park Grand Prix Circuit     Melbourne
# 1          2       sepang    Sepang International Circuit  Kuala Lumpur
# 2          3      bahrain   Bahrain International Circuit        Sakhir
# 3          4    catalunya  Circuit de Barcelona-Catalunya      Montmeló
# 4          5     istanbul                   Istanbul Park      Istanbul
#
#      country       lat        lng
# 0  Australia -37.84970  144.96800
# 1   Malaysia   2.76083  101.73800
# 2    Bahrain  26.03250   50.51060
# 3      Spain  41.57000    2.26111
# 4     Turkey  40.95170   29.40500

# %%
race_info = pd.merge(races, circuits, on='circuitId', how='left')

race_info.head()
# Out:
#    raceId  year  round  circuitId                    name_x        date  \
# 0    1098  2023      1          3        Bahrain Grand Prix  2023-03-05
# 1    1099  2023      2         77  Saudi Arabian Grand Prix  2023-03-19
# 2    1100  2023      3          1     Australian Grand Prix  2023-04-02
# 3    1101  2023      4         73     Azerbaijan Grand Prix  2023-04-30
# 4    1102  2023      5         79          Miami Grand Prix  2023-05-07
#
#        time   circuitRef                          name_y   location  \
# 0  15:00:00      bahrain   Bahrain International Circuit     Sakhir
# 1  17:00:00       jeddah         Jeddah Corniche Circuit     Jeddah
# 2  05:00:00  albert_park  Albert Park Grand Prix Circuit  Melbourne
# 3  11:00:00         baku               Baku City Circuit       Baku
# 4  19:30:00        miami   Miami International Autodrome      Miami
#
#         country      lat       lng
# 0       Bahrain  26.0325   50.5106
# 1  Saudi Arabia  21.6319   39.1044
# ...

# %%
race_info.shape
# Out:
# (1090, 13)

# %%
race_info.rename(columns={'name_x':'race', 'name_y':'circuit'}, inplace=True)

race_info.sample(5)
# Out:
#      raceId  year  round  circuitId                race        date      time  \
# 53     1061  2021     10          9  British Grand Prix  2021-07-18  14:00:00
# 111     996  2018      8         34   French Grand Prix  2018-06-24  14:10:00
# 652     391  1987      4          6   Monaco Grand Prix  1987-05-31        \N
# 385     105  2004     16         17  Chinese Grand Prix  2004-09-26        \N
# 180     941  2015     15         71  Russian Grand Prix  2015-10-11  11:00:00
#
#       circuitRef                         circuit      location country  \
# 53   silverstone             Silverstone Circuit   Silverstone      UK
# 111       ricard             Circuit Paul Ricard  Le Castellet  France
# 652       monaco               Circuit de Monaco   Monte-Carlo  Monaco
# 385     shanghai  Shanghai International Circuit      Shanghai   China
# 180        sochi                  Sochi Autodrom         Sochi  Russia
#
#          lat        lng
# 53   52.0786   -1.01694
# ...

# %%
race_info['time'].value_counts()
# Out:
# \N          720
# 12:00:00    112
# 13:00:00     41
# 14:00:00     34
# 13:10:00     30
# 06:00:00     20
# 05:00:00     12
# 19:00:00     12
# 16:00:00     11
# 07:00:00     11
# 15:00:00     11
# 18:00:00      9
# 17:00:00      9
# 12:10:00      6
# 11:00:00      6
# 08:00:00      5
# 05:10:00      4
# 20:00:00      3
# 19:10:00      3
# 04:30:00      3
# 09:30:00      3
# 18:10:00      3
# 17:10:00      3
# 11:10:00      3
# 06:10:00      2
# 19:30:00      2
# 15:10:00      2
# 11:30:00      2
# 14:30:00      2
# 14:10:00      2
# 17:30:00      1
# 10:10:00      1
# 09:00:00      1
# 03:00:00      1
# Name: time, dtype: int64

# %%
race_info.drop(columns='time', inplace=True)

race_info.shape
# Out:
# (1090, 12)

# %%
race_info.sample(5)
# Out:
#       raceId  year  round  circuitId                      race        date  \
# 159      962  2016     15         15      Singapore Grand Prix  2016-09-18
# 46      1054  2021      3         75     Portuguese Grand Prix  2021-05-02
# 1014     754  1960      9         14        Italian Grand Prix  1960-09-04
# 727      466  1983     15         30  South African Grand Prix  1983-10-15
# 230      867  2012      8         12       European Grand Prix  2012-06-24
#
#       circuitRef                             circuit    location  \
# 159   marina_bay           Marina Bay Street Circuit  Marina Bay
# 46      portimao  Autódromo Internacional do Algarve    Portimão
# 1014       monza        Autodromo Nazionale di Monza       Monza
# 727      kyalami                             Kyalami     Midrand
# 230     valencia             Valencia Street Circuit    Valencia
#
#            country      lat         lng
# 159      Singapore   1.2914  103.864000
# 46        Portugal  37.2270   -8.626700
# ...

# %%
race_info.columns.tolist()
# Out:
# ['raceId',
#  'year',
#  'round',
#  'circuitId',
#  'race',
#  'date',
#  'circuitRef',
#  'circuit',
#  'location',
#  'country',
#  'lat',
#  'lng']

# %%
cols = ['year', 'round', 'race', 'date', 'country', 'location', 'circuit', 'circuitRef', 'lat', 'lng', 'raceId', 'circuitId']

race_info = race_info[cols]

race_info.shape
# Out:
# (1090, 12)

# %%
race_info.head()
# Out:
#    year  round                      race        date       country   location  \
# 0  2023      1        Bahrain Grand Prix  2023-03-05       Bahrain     Sakhir
# 1  2023      2  Saudi Arabian Grand Prix  2023-03-19  Saudi Arabia     Jeddah
# 2  2023      3     Australian Grand Prix  2023-04-02     Australia  Melbourne
# 3  2023      4     Azerbaijan Grand Prix  2023-04-30    Azerbaijan       Baku
# 4  2023      5          Miami Grand Prix  2023-05-07           USA      Miami
#
#                           circuit   circuitRef      lat       lng  raceId  \
# 0   Bahrain International Circuit      bahrain  26.0325   50.5106    1098
# 1         Jeddah Corniche Circuit       jeddah  21.6319   39.1044    1099
# 2  Albert Park Grand Prix Circuit  albert_park -37.8497  144.9680    1100
# 3               Baku City Circuit         baku  40.3725   49.8533    1101
# 4   Miami International Autodrome        miami  25.9581  -80.2389    1102
#
#    circuitId
# 0          3
# 1         77
# ...

# %%
f1_23 = race_info.loc[race_info['year'] == 2023]

# %%
race_info.loc[race_info['year'] == 2021]
# Out:
#     year  round                       race        date       country  \
# 44  2021      1         Bahrain Grand Prix  2021-03-28       Bahrain
# 45  2021      2  Emilia Romagna Grand Prix  2021-04-18         Italy
# 46  2021      3      Portuguese Grand Prix  2021-05-02      Portugal
# 47  2021      4         Spanish Grand Prix  2021-05-09         Spain
# 48  2021      5          Monaco Grand Prix  2021-05-23        Monaco
# 49  2021      6      Azerbaijan Grand Prix  2021-06-06    Azerbaijan
# 50  2021      7          French Grand Prix  2021-06-20        France
# 51  2021      8         Styrian Grand Prix  2021-06-27       Austria
# 52  2021      9        Austrian Grand Prix  2021-07-04       Austria
# 53  2021     10         British Grand Prix  2021-07-18            UK
# 54  2021     11       Hungarian Grand Prix  2021-08-01       Hungary
# 55  2021     12         Belgian Grand Prix  2021-08-29       Belgium
# 56  2021     13           Dutch Grand Prix  2021-09-05   Netherlands
# ...

# %%
f1_23
# Out:
#     year  round                      race        date        country  \
# 0   2023      1        Bahrain Grand Prix  2023-03-05        Bahrain
# 1   2023      2  Saudi Arabian Grand Prix  2023-03-19   Saudi Arabia
# 2   2023      3     Australian Grand Prix  2023-04-02      Australia
# 3   2023      4     Azerbaijan Grand Prix  2023-04-30     Azerbaijan
# 4   2023      5          Miami Grand Prix  2023-05-07            USA
# 5   2023      6         Monaco Grand Prix  2023-05-28         Monaco
# 6   2023      7        Spanish Grand Prix  2023-06-04          Spain
# 7   2023      8       Canadian Grand Prix  2023-06-18         Canada
# 8   2023      9       Austrian Grand Prix  2023-07-02        Austria
# 9   2023     10        British Grand Prix  2023-07-09             UK
# 10  2023     11      Hungarian Grand Prix  2023-07-23        Hungary
# 11  2023     12        Belgian Grand Prix  2023-07-30        Belgium
# 12  2023     13          Dutch Grand Prix  2023-08-27    Netherlands
# ...

# %%
lat1 = f1_23.loc[f1_23['round'] == 1, 'lat'].values[0]
lng1 = f1_23.loc[f1_23['round'] == 1, 'lng'].values[0]
loc1 = f1_23.loc[f1_23['round'] == 1, 'circuitRef'].values[0]

#print(loc1, lat1, lng1)

total = 0

for index, row in f1_23.iterrows():
    #print(row['circuitRef'])
    r = row['round']
    if r>1:
        lat2 = row['lat']
        lng2 = row['lng']
        loc2 = row['circuitRef']
        
        dist = hs.haversine((lat1, lng1), (lat2, lng2))
        print(loc1, '<->', loc2, "=", round(dist, 2), "kms\n")
        total = total + dist
        
        lat1 = lat2
        lng1 = lng2
        loc1 = loc2
        
        #print(r)
        
print("\nF1 2023 Total Distance : {0} kilometres".format(round(total, 2)))
# Out:
# bahrain <-> jeddah = 1258.43 kms
#
# jeddah <-> albert_park = 12817.12 kms
#
# albert_park <-> baku = 12989.08 kms
#
# baku <-> miami = 11015.93 kms
#
# miami <-> monaco = 7870.83 kms
#
# monaco <-> catalunya = 485.64 kms
#
# catalunya <-> villeneuve = 5891.51 kms
#
# villeneuve <-> red_bull_ring = 6390.49 kms
#
# red_bull_ring <-> silverstone = 1254.64 kms
#
# silverstone <-> hungaroring = 1531.29 kms
#
# hungaroring <-> spa = 1017.59 kms
#
# spa <-> zandvoort = 238.6 kms
#
# zandvoort <-> monza = 828.29 kms
#
# monza <-> marina_bay = 10260.98 kms
#
# marina_bay <-> suzuka = 5035.99 kms
#
# suzuka <-> losail = 8003.99 kms
#
# losail <-> americas = 13008.46 kms
#
# americas <-> rodriguez = 1201.87 kms
#
# rodriguez <-> interlagos = 7430.98 kms
#
# interlagos <-> vegas = 9787.88 kms
#
# vegas <-> yas_marina = 13193.63 kms
#
#
# F1 2023 Total Distance : 131513.24 kilometres

# %%
def dist_calc(year, disp=False):
    cal = race_info.loc[race_info['year'] == year]
    
    rounds = cal.shape[0]
    lat1 = cal.loc[cal['round'] == 1, 'lat'].values[0]
    lng1 = cal.loc[cal['round'] == 1, 'lng'].values[0]
    loc1 = cal.loc[cal['round'] == 1, 'location'].values[0]

    
    total = 0

    for index, row in cal.iterrows():
        #print(row['circuitRef'])
        r = row['round']
        if r>1:
            lat2 = row['lat']
            lng2 = row['lng']
            loc2 = row['location']
        
            dist = hs.haversine((lat1, lng1), (lat2, lng2))
            
            if disp==True:
                print(loc1, '<->', loc2, "=", round(dist, 2), "kms\n")
            total = total + dist
        
            lat1 = lat2
            lng1 = lng2
            loc1 = loc2
        
            #print(r)
    if disp==True:
        print("-----------------------------------------")
    
        print("\nF1 {0} Total Distance : {1} kilometres".format(year, round(total, 2)))
    
    return round(total, 2), rounds

# %%
dist_calc(2023, True)
# Out:
# Sakhir <-> Jeddah = 1258.43 kms
#
# Jeddah <-> Melbourne = 12817.12 kms
#
# Melbourne <-> Baku = 12989.08 kms
#
# Baku <-> Miami = 11015.93 kms
#
# Miami <-> Monte-Carlo = 7870.83 kms
#
# Monte-Carlo <-> Montmeló = 485.64 kms
#
# Montmeló <-> Montreal = 5891.51 kms
#
# Montreal <-> Spielberg = 6390.49 kms
#
# Spielberg <-> Silverstone = 1254.64 kms
#
# Silverstone <-> Budapest = 1531.29 kms
#
# Budapest <-> Spa = 1017.59 kms
#
# Spa <-> Zandvoort = 238.6 kms
#
# Zandvoort <-> Monza = 828.29 kms
#
# Monza <-> Marina Bay = 10260.98 kms
#
# Marina Bay <-> Suzuka = 5035.99 kms
#
# Suzuka <-> Al Daayen = 8003.99 kms
#
# Al Daayen <-> Austin = 13008.46 kms
#
# Austin <-> Mexico City = 1201.87 kms
#
# Mexico City <-> São Paulo = 7430.98 kms
#
# São Paulo <-> Las Vegas = 9787.88 kms
#
# Las Vegas <-> Abu Dhabi = 13193.63 kms
#
# -----------------------------------------
#
# F1 2023 Total Distance : 131513.24 kilometres
# (131513.24, 22)

# %%
dist_calc(2022)
# Out:
# (116138.73, 22)

# %%
dist_calc(2021, True)
# Out:
# Sakhir <-> Imola = 4018.27 kms
#
# Imola <-> Portimão = 1880.0 kms
#
# Portimão <-> Montmeló = 1051.73 kms
#
# Montmeló <-> Monte-Carlo = 485.64 kms
#
# Monte-Carlo <-> Baku = 3484.89 kms
#
# Baku <-> Le Castellet = 3623.4 kms
#
# Le Castellet <-> Spielberg = 828.95 kms
#
# Spielberg <-> Spielberg = 0.0 kms
#
# Spielberg <-> Silverstone = 1254.64 kms
#
# Silverstone <-> Budapest = 1531.29 kms
#
# Budapest <-> Spa = 1017.59 kms
#
# Spa <-> Zandvoort = 238.6 kms
#
# Zandvoort <-> Monza = 828.29 kms
#
# Monza <-> Sochi = 2429.93 kms
#
# Sochi <-> Istanbul = 910.63 kms
#
# Istanbul <-> Austin = 10418.76 kms
#
# Austin <-> Mexico City = 1201.87 kms
#
# Mexico City <-> São Paulo = 7430.98 kms
#
# São Paulo <-> Al Daayen = 11883.61 kms
#
# Al Daayen <-> Jeddah = 1329.13 kms
#
# Jeddah <-> Abu Dhabi = 1615.85 kms
#
# -----------------------------------------
#
# F1 2021 Total Distance : 57464.04 kilometres
# (57464.04, 22)

# %%
for i in range(1950,2024):
    dist, rounds = dist_calc(i)
    avg = round(dist/rounds, 2)
    print(i, '-',rounds, 'rounds -',  dist, 'kms', '-', avg, 'kms per race')
# Out:
# 1950 - 6 rounds - 2645.62 kms - 440.94 kms per race
# 1951 - 7 rounds - 2950.93 kms - 421.56 kms per race
# 1952 - 7 rounds - 2812.77 kms - 401.82 kms per race
# 1953 - 8 rounds - 13517.44 kms - 1689.68 kms per race
# 1954 - 8 rounds - 13955.79 kms - 1744.47 kms per race
# 1955 - 6 rounds - 13717.35 kms - 2286.22 kms per race
# 1956 - 7 rounds - 13530.74 kms - 1932.96 kms per race
# 1957 - 7 rounds - 14617.02 kms - 2088.15 kms per race
# 1958 - 10 rounds - 18523.99 kms - 1852.4 kms per race
# 1959 - 8 rounds - 15012.07 kms - 1876.51 kms per race
# 1960 - 9 rounds - 25402.39 kms - 2822.49 kms per race
# 1961 - 8 rounds - 9961.58 kms - 1245.2 kms per race
# 1962 - 9 rounds - 24056.3 kms - 2672.92 kms per race
# 1963 - 10 rounds - 27372.22 kms - 2737.22 kms per race
# 1964 - 10 rounds - 13287.21 kms - 1328.72 kms per race
# 1965 - 10 rounds - 21933.21 kms - 2193.32 kms per race
# 1966 - 9 rounds - 12299.86 kms - 1366.65 kms per race
# ...

# %%
race_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1090 entries, 0 to 1089
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        1090 non-null   int64
#  1   round       1090 non-null   int64
#  2   race        1090 non-null   object
#  3   date        1090 non-null   object
#  4   country     1090 non-null   object
#  5   location    1090 non-null   object
#  6   circuit     1090 non-null   object
#  7   circuitRef  1090 non-null   object
#  8   lat         1090 non-null   float64
#  9   lng         1090 non-null   float64
#  10  raceId      1090 non-null   int64
#  11  circuitId   1090 non-null   int64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 110.7+ KB

# %%
f = '%Y-%m-%d'

race_info['date'] = pd.to_datetime(race_info['date'], format=f).dt.date

race_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1090 entries, 0 to 1089
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        1090 non-null   int64
#  1   round       1090 non-null   int64
#  2   race        1090 non-null   object
#  3   date        1090 non-null   object
#  4   country     1090 non-null   object
#  5   location    1090 non-null   object
#  6   circuit     1090 non-null   object
#  7   circuitRef  1090 non-null   object
#  8   lat         1090 non-null   float64
#  9   lng         1090 non-null   float64
#  10  raceId      1090 non-null   int64
#  11  circuitId   1090 non-null   int64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 110.7+ KB

# %%
race_info.loc[0]
# Out:
# year                                   2023
# round                                     1
# race                     Bahrain Grand Prix
# date                             2023-03-05
# country                             Bahrain
# location                             Sakhir
# circuit       Bahrain International Circuit
# circuitRef                          bahrain
# lat                                 26.0325
# lng                                 50.5106
# raceId                                 1098
# circuitId                                 3
# Name: 0, dtype: object

# %%
race_info.loc[1]
# Out:
# year                              2023
# round                                2
# race          Saudi Arabian Grand Prix
# date                        2023-03-19
# country                   Saudi Arabia
# location                        Jeddah
# circuit        Jeddah Corniche Circuit
# circuitRef                      jeddah
# lat                            21.6319
# lng                            39.1044
# raceId                            1099
# circuitId                           77
# Name: 1, dtype: object

# %%
d1 = race_info.loc[0, ['date']].values[0]
d2 = race_info.loc[1, ['date']].values[0]

print(d1, d2)
print(type(d1), type(d2))
# Out:
# 2023-03-05 2023-03-19
# <class 'datetime.date'> <class 'datetime.date'>

# %%
d1 - timedelta(days=d1.weekday())
# Out:
# datetime.date(2023, 2, 27)

# %%
d2 - timedelta(days=d2.weekday())
# Out:
# datetime.date(2023, 3, 13)

# %%
int((d2-d1).days/7)
# Out:
# 2

# %%
i = 0
for index, row in race_info.iterrows():
    if row['round'] == 1:
        gap = 0
        
        #print(row['year'])
        i = i+1
    else:
        d2 = row['date']
        d1 = race_info.loc[(index-1), 'date']
        
        m2 = d2 - timedelta(days=d2.weekday())
        m1 = d1 - timedelta(days=d1.weekday())
        
        gap = (m2-m1).days/7
        
    race_info.loc[index, 'gap'] = gap
#print(i)

#race_info['round'].value_counts()

race_info['gap'] = race_info['gap'].astype(int)

race_info.head(25)
# Out:
#     year  round                      race        date        country  \
# 0   2023      1        Bahrain Grand Prix  2023-03-05        Bahrain
# 1   2023      2  Saudi Arabian Grand Prix  2023-03-19   Saudi Arabia
# 2   2023      3     Australian Grand Prix  2023-04-02      Australia
# 3   2023      4     Azerbaijan Grand Prix  2023-04-30     Azerbaijan
# 4   2023      5          Miami Grand Prix  2023-05-07            USA
# 5   2023      6         Monaco Grand Prix  2023-05-28         Monaco
# 6   2023      7        Spanish Grand Prix  2023-06-04          Spain
# 7   2023      8       Canadian Grand Prix  2023-06-18         Canada
# 8   2023      9       Austrian Grand Prix  2023-07-02        Austria
# 9   2023     10        British Grand Prix  2023-07-09             UK
# 10  2023     11      Hungarian Grand Prix  2023-07-23        Hungary
# 11  2023     12        Belgian Grand Prix  2023-07-30        Belgium
# 12  2023     13          Dutch Grand Prix  2023-08-27    Netherlands
# ...

# %%
cols = race_info.columns.tolist()

print(cols)
# Out:
# ['year', 'round', 'race', 'date', 'country', 'location', 'circuit', 'circuitRef', 'lat', 'lng', 'raceId', 'circuitId', 'gap']

# %%
cols = ['year', 'round', 'race', 'date', 'gap', 'country', 'location', 'circuit', 'circuitRef', 'lat', 'lng', 'raceId', 'circuitId']

race_info = race_info[cols]

race_info
# Out:
#       year  round                           race        date  gap  \
# 0     2023      1             Bahrain Grand Prix  2023-03-05    0
# 1     2023      2       Saudi Arabian Grand Prix  2023-03-19    2
# 2     2023      3          Australian Grand Prix  2023-04-02    2
# 3     2023      4          Azerbaijan Grand Prix  2023-04-30    4
# 4     2023      5               Miami Grand Prix  2023-05-07    1
# 5     2023      6              Monaco Grand Prix  2023-05-28    3
# 6     2023      7             Spanish Grand Prix  2023-06-04    1
# 7     2023      8            Canadian Grand Prix  2023-06-18    2
# 8     2023      9            Austrian Grand Prix  2023-07-02    2
# 9     2023     10             British Grand Prix  2023-07-09    1
# 10    2023     11           Hungarian Grand Prix  2023-07-23    2
# 11    2023     12             Belgian Grand Prix  2023-07-30    1
# 12    2023     13               Dutch Grand Prix  2023-08-27    4
# ...

# %%
def display_season(year):
    r = race_info.loc[race_info['year'] == year]
    
    return r

# %%
display_season(2023)
# Out:
#     year  round                      race        date  gap        country  \
# 0   2023      1        Bahrain Grand Prix  2023-03-05    0        Bahrain
# 1   2023      2  Saudi Arabian Grand Prix  2023-03-19    2   Saudi Arabia
# 2   2023      3     Australian Grand Prix  2023-04-02    2      Australia
# 3   2023      4     Azerbaijan Grand Prix  2023-04-30    4     Azerbaijan
# 4   2023      5          Miami Grand Prix  2023-05-07    1            USA
# 5   2023      6         Monaco Grand Prix  2023-05-28    3         Monaco
# 6   2023      7        Spanish Grand Prix  2023-06-04    1          Spain
# 7   2023      8       Canadian Grand Prix  2023-06-18    2         Canada
# 8   2023      9       Austrian Grand Prix  2023-07-02    2        Austria
# 9   2023     10        British Grand Prix  2023-07-09    1             UK
# 10  2023     11      Hungarian Grand Prix  2023-07-23    2        Hungary
# 11  2023     12        Belgian Grand Prix  2023-07-30    1        Belgium
# ...

# %%
display_season(2021)
# Out:
#     year  round                       race        date  gap       country  \
# 44  2021      1         Bahrain Grand Prix  2021-03-28    0       Bahrain
# 45  2021      2  Emilia Romagna Grand Prix  2021-04-18    3         Italy
# 46  2021      3      Portuguese Grand Prix  2021-05-02    2      Portugal
# 47  2021      4         Spanish Grand Prix  2021-05-09    1         Spain
# 48  2021      5          Monaco Grand Prix  2021-05-23    2        Monaco
# 49  2021      6      Azerbaijan Grand Prix  2021-06-06    2    Azerbaijan
# 50  2021      7          French Grand Prix  2021-06-20    2        France
# 51  2021      8         Styrian Grand Prix  2021-06-27    1       Austria
# 52  2021      9        Austrian Grand Prix  2021-07-04    1       Austria
# 53  2021     10         British Grand Prix  2021-07-18    2            UK
# 54  2021     11       Hungarian Grand Prix  2021-08-01    2       Hungary
# 55  2021     12         Belgian Grand Prix  2021-08-29    4       Belgium
# ...

# %%
for year in range(1950, 2024):
    last = race_info.loc[race_info['year'] == year, 'round'].values.max()
    
    print(year, last)

#race_info.loc[race_info['year'] == 2023, 'round'].values.max()
# Out:
# 1950 7
# 1951 8
# 1952 8
# 1953 9
# 1954 9
# 1955 7
# 1956 8
# 1957 8
# 1958 11
# 1959 9
# 1960 10
# 1961 8
# 1962 9
# 1963 10
# 1964 10
# 1965 10
# 1966 9
# 1967 11
# 1968 12
# 1969 11
# 1970 13
# 1971 11
# 1972 12
# 1973 15
# 1974 15
# 1975 14
# 1976 16
# 1977 17
# 1978 16
# 1979 15
# 1980 14
# 1981 15
# 1982 16
# 1983 15
# 1984 16
# 1985 16
# 1986 16
# 1987 16
# 1988 16
# 1989 16
# 1990 16
# 1991 16
# 1992 16
# 1993 16
# 1994 16
# 1995 17
# 1996 16
# 1997 17
# 1998 16
# 1999 16
# 2000 17
# 2001 17
# 2002 17
# 2003 16
# 2004 18
# 2005 19
# 2006 18
# 2007 17
# 2008 18
# 2009 17
# 2010 19
# 2011 19
# 2012 20
# 2013 19
# 2014 19
# 2015 19
# 2016 21
# 2017 20
# 2018 21
# 2019 21
# 2020 17
# 2021 22
# 2022 22
# 2023 22

# %%
for index, row in race_info.iterrows():
    year = row['year']
    last = race_info.loc[race_info['year'] == year, 'round'].values.max()
    
    if row['round'] == 1:
        if race_info.loc[(index+1), 'gap'] == 1:
            if race_info.loc[(index+2), 'gap'] == 1:
                header = "triple"
            else:
                header = "double"
        else:
            header = "single"
    
    elif row['round'] < last-1:
        if row['gap'] == 1:
            if (race_info.loc[(index+1), 'gap'] == 1) or (race_info.loc[(index-1), 'gap'] == 1):
                header = "triple"
            else:
                header = "double"
        
        elif race_info.loc[(index+1), 'gap'] == 1:
            if race_info.loc[(index+2), 'gap'] == 1:
                header = "triple"
            else:
                header = "double"
        else:
            header = "single"
            
    elif row['round'] == last-1:
        if row['gap'] == 1:
            if (race_info.loc[(index+1), 'gap'] == 1) or (race_info.loc[(index-1), 'gap'] == 1):
                header = "triple"
            else:
                header = "double"
                
        elif race_info.loc[(index+1), 'gap'] == 1:
            header = "double"
                
        else:
            header = "single"
    
    else:
        if row['gap'] == 1:
            if race_info.loc[(index-1), 'gap'] == 1:
                header = "triple"
            else:
                header = "double"
        else:
            header = "single"
    
    race_info.loc[index, 'header'] = header

# %%
cols = ['year', 'round', 'race', 'date', 'header', 'gap', 'country', 'location', 'circuit', 'circuitRef', 'lat', 'lng', 'raceId', 'circuitId']

race_info = race_info[cols]

race_info
# Out:
#       year  round                           race        date  header  gap  \
# 0     2023      1             Bahrain Grand Prix  2023-03-05  single    0
# 1     2023      2       Saudi Arabian Grand Prix  2023-03-19  single    2
# 2     2023      3          Australian Grand Prix  2023-04-02  single    2
# 3     2023      4          Azerbaijan Grand Prix  2023-04-30  double    4
# 4     2023      5               Miami Grand Prix  2023-05-07  double    1
# 5     2023      6              Monaco Grand Prix  2023-05-28  double    3
# 6     2023      7             Spanish Grand Prix  2023-06-04  double    1
# 7     2023      8            Canadian Grand Prix  2023-06-18  single    2
# 8     2023      9            Austrian Grand Prix  2023-07-02  double    2
# 9     2023     10             British Grand Prix  2023-07-09  double    1
# 10    2023     11           Hungarian Grand Prix  2023-07-23  double    2
# 11    2023     12             Belgian Grand Prix  2023-07-30  double    1
# ...

# %%
display_season(2023)
# Out:
#     year  round                      race        date  header  gap  \
# 0   2023      1        Bahrain Grand Prix  2023-03-05  single    0
# 1   2023      2  Saudi Arabian Grand Prix  2023-03-19  single    2
# 2   2023      3     Australian Grand Prix  2023-04-02  single    2
# 3   2023      4     Azerbaijan Grand Prix  2023-04-30  double    4
# 4   2023      5          Miami Grand Prix  2023-05-07  double    1
# 5   2023      6         Monaco Grand Prix  2023-05-28  double    3
# 6   2023      7        Spanish Grand Prix  2023-06-04  double    1
# 7   2023      8       Canadian Grand Prix  2023-06-18  single    2
# 8   2023      9       Austrian Grand Prix  2023-07-02  double    2
# 9   2023     10        British Grand Prix  2023-07-09  double    1
# 10  2023     11      Hungarian Grand Prix  2023-07-23  double    2
# 11  2023     12        Belgian Grand Prix  2023-07-30  double    1
# 12  2023     13          Dutch Grand Prix  2023-08-27  double    4
# ...

# %%
display_season(2021)
# Out:
#     year  round                       race        date  header  gap  \
# 44  2021      1         Bahrain Grand Prix  2021-03-28  single    0
# 45  2021      2  Emilia Romagna Grand Prix  2021-04-18  single    3
# 46  2021      3      Portuguese Grand Prix  2021-05-02  double    2
# 47  2021      4         Spanish Grand Prix  2021-05-09  double    1
# 48  2021      5          Monaco Grand Prix  2021-05-23  single    2
# 49  2021      6      Azerbaijan Grand Prix  2021-06-06  single    2
# 50  2021      7          French Grand Prix  2021-06-20  triple    2
# 51  2021      8         Styrian Grand Prix  2021-06-27  triple    1
# 52  2021      9        Austrian Grand Prix  2021-07-04  triple    1
# 53  2021     10         British Grand Prix  2021-07-18  single    2
# 54  2021     11       Hungarian Grand Prix  2021-08-01  single    2
# 55  2021     12         Belgian Grand Prix  2021-08-29  triple    4
# 56  2021     13           Dutch Grand Prix  2021-09-05  triple    1
# ...

# %%
def header_count(year):
    season = race_info.loc[race_info['year'] == year]
    
    single = double = triple = 0
    double_dup = triple_dup = False
    
    for index, row in season.iterrows():
        if row['gap'] > 1:
            double_dup = triple_dup = False
            
        if row['header'] == 'single':
            single = single + 1
        elif row['header'] == 'double':
            if double_dup == False:
                double = double + 1
            double_dup = True
        elif row['header'] == 'triple':
            if triple_dup == False:
                triple = triple + 1
            triple_dup = True

    
    return single, double, triple

# %%
print(header_count(2023))
# Out:
# (5, 7, 1)

# %%
print(header_count(2022))
# Out:
# (3, 8, 1)

# %%
for i in range(1950, 2024):
    print(i, header_count(i))
# Out:
# 1950 (4, 1, 0)
# 1951 (7, 0, 0)
# 1952 (7, 0, 0)
# 1953 (8, 0, 0)
# 1954 (8, 0, 0)
# 1955 (6, 0, 0)
# 1956 (7, 0, 0)
# 1957 (7, 0, 0)
# 1958 (10, 0, 0)
# 1959 (8, 0, 0)
# 1960 (7, 1, 0)
# 1961 (8, 0, 0)
# 1962 (9, 0, 0)
# 1963 (8, 1, 0)
# 1964 (10, 0, 0)
# 1965 (8, 1, 0)
# 1966 (7, 1, 0)
# 1967 (11, 0, 0)
# 1968 (12, 0, 0)
# 1969 (11, 0, 0)
# 1970 (13, 0, 0)
# 1971 (11, 0, 0)
# 1972 (10, 1, 0)
# 1973 (13, 1, 0)
# 1974 (15, 0, 0)
# 1975 (14, 0, 0)
# 1976 (14, 1, 0)
# 1977 (15, 1, 0)
# 1978 (14, 1, 0)
# 1979 (13, 1, 0)
# 1980 (10, 2, 0)
# 1981 (15, 0, 0)
# 1982 (10, 3, 0)
# 1983 (9, 3, 0)
# 1984 (10, 3, 0)
# 1985 (10, 3, 0)
# 1986 (10, 3, 0)
# 1987 (10, 3, 0)
# 1988 (10, 3, 0)
# 1989 (10, 3, 0)
# 1990 (12, 2, 0)
# 1991 (12, 2, 0)
# 1992 (14, 1, 0)
# 1993 (14, 1, 0)
# 1994 (12, 2, 0)
# 1995 (13, 2, 0)
# 1996 (12, 2, 0)
# 1997 (15, 1, 0)
# 1998 (14, 1, 0)
# 1999 (14, 1, 0)
# 2000 (17, 0, 0)
# 2001 (15, 1, 0)
# 2002 (15, 1, 0)
# 2003 (14, 1, 0)
# 2004 (12, 3, 0)
# 2005 (7, 6, 0)
# ...

# %%
display_season(2000)
# Out:
#      year  round                      race        date  header  gap  \
# 438  2000      1     Australian Grand Prix  2000-03-12  single    0
# 439  2000      2      Brazilian Grand Prix  2000-03-26  single    2
# 440  2000      3     San Marino Grand Prix  2000-04-09  single    2
# 441  2000      4        British Grand Prix  2000-04-23  single    2
# 442  2000      5        Spanish Grand Prix  2000-05-07  single    2
# 443  2000      6       European Grand Prix  2000-05-21  single    2
# 444  2000      7         Monaco Grand Prix  2000-06-04  single    2
# 445  2000      8       Canadian Grand Prix  2000-06-18  single    2
# 446  2000      9         French Grand Prix  2000-07-02  single    2
# 447  2000     10       Austrian Grand Prix  2000-07-16  single    2
# 448  2000     11         German Grand Prix  2000-07-30  single    2
# 449  2000     12      Hungarian Grand Prix  2000-08-13  single    2
# 450  2000     13        Belgian Grand Prix  2000-08-27  single    2
# ...

# %%
display_season(2022)
# Out:
#     year  round                       race        date  header  gap  \
# 22  2022      1         Bahrain Grand Prix  2022-03-20  double    0
# 23  2022      2   Saudi Arabian Grand Prix  2022-03-27  double    1
# 24  2022      3      Australian Grand Prix  2022-04-10  single    2
# 25  2022      4  Emilia Romagna Grand Prix  2022-04-24  single    2
# 26  2022      5           Miami Grand Prix  2022-05-08  single    2
# 27  2022      6         Spanish Grand Prix  2022-05-22  double    2
# 28  2022      7          Monaco Grand Prix  2022-05-29  double    1
# 29  2022      8      Azerbaijan Grand Prix  2022-06-12  double    2
# 30  2022      9        Canadian Grand Prix  2022-06-19  double    1
# 31  2022     10         British Grand Prix  2022-07-03  double    2
# 32  2022     11        Austrian Grand Prix  2022-07-10  double    1
# 33  2022     12          French Grand Prix  2022-07-24  double    2
# 34  2022     13       Hungarian Grand Prix  2022-07-31  double    1
# ...

# %%
race_info.head(25)
# Out:
#     year  round                      race        date  header  gap  \
# 0   2023      1        Bahrain Grand Prix  2023-03-05  single    0
# 1   2023      2  Saudi Arabian Grand Prix  2023-03-19  single    2
# 2   2023      3     Australian Grand Prix  2023-04-02  single    2
# 3   2023      4     Azerbaijan Grand Prix  2023-04-30  double    4
# 4   2023      5          Miami Grand Prix  2023-05-07  double    1
# 5   2023      6         Monaco Grand Prix  2023-05-28  double    3
# 6   2023      7        Spanish Grand Prix  2023-06-04  double    1
# 7   2023      8       Canadian Grand Prix  2023-06-18  single    2
# 8   2023      9       Austrian Grand Prix  2023-07-02  double    2
# 9   2023     10        British Grand Prix  2023-07-09  double    1
# 10  2023     11      Hungarian Grand Prix  2023-07-23  double    2
# 11  2023     12        Belgian Grand Prix  2023-07-30  double    1
# 12  2023     13          Dutch Grand Prix  2023-08-27  double    4
# ...

# %%
race_info.drop('distance', axis=1, inplace=True)

race_info.head()
# Out:
#    year  round                      race        date  header  gap  \
# 0  2023      1        Bahrain Grand Prix  2023-03-05  single    0
# 1  2023      2  Saudi Arabian Grand Prix  2023-03-19  single    2
# 2  2023      3     Australian Grand Prix  2023-04-02  single    2
# 3  2023      4     Azerbaijan Grand Prix  2023-04-30  double    4
# 4  2023      5          Miami Grand Prix  2023-05-07  double    1
#
#         country   location                         circuit   circuitRef  \
# 0       Bahrain     Sakhir   Bahrain International Circuit      bahrain
# 1  Saudi Arabia     Jeddah         Jeddah Corniche Circuit       jeddah
# 2     Australia  Melbourne  Albert Park Grand Prix Circuit  albert_park
# 3    Azerbaijan       Baku               Baku City Circuit         baku
# 4           USA      Miami   Miami International Autodrome        miami
#
#        lat       lng  raceId  circuitId
# 0  26.0325   50.5106    1098          3
# 1  21.6319   39.1044    1099         77
# ...

# %%
for index, row in race_info.iterrows():
    #print(row['round'], row['location'])
    
    if row['round'] == 1:
        dist = 0
    else:
        lat1 = race_info.loc[(index-1), 'lat']
        lng1 = race_info.loc[(index-1), 'lng']
        
        lat2 = row['lat']
        lng2 = row['lng']
        
        loc2 = row['location']
        
        dist = round(hs.haversine((lat1, lng1), (lat2, lng2)), 2)
        
    #print(row['round'], row['location'], dist)
    race_info.loc[index, 'distance (km)'] = dist

# %%
race_info.head(50)
# Out:
#     year  round                       race        date  header  gap  \
# 0   2023      1         Bahrain Grand Prix  2023-03-05  single    0
# 1   2023      2   Saudi Arabian Grand Prix  2023-03-19  single    2
# 2   2023      3      Australian Grand Prix  2023-04-02  single    2
# 3   2023      4      Azerbaijan Grand Prix  2023-04-30  double    4
# 4   2023      5           Miami Grand Prix  2023-05-07  double    1
# 5   2023      6          Monaco Grand Prix  2023-05-28  double    3
# 6   2023      7         Spanish Grand Prix  2023-06-04  double    1
# 7   2023      8        Canadian Grand Prix  2023-06-18  single    2
# 8   2023      9        Austrian Grand Prix  2023-07-02  double    2
# 9   2023     10         British Grand Prix  2023-07-09  double    1
# 10  2023     11       Hungarian Grand Prix  2023-07-23  double    2
# 11  2023     12         Belgian Grand Prix  2023-07-30  double    1
# 12  2023     13           Dutch Grand Prix  2023-08-27  double    4
# ...

# %%
cols = race_info.columns.tolist()

print(cols)
# Out:
# ['year', 'round', 'race', 'date', 'header', 'gap', 'country', 'location', 'circuit', 'circuitRef', 'lat', 'lng', 'raceId', 'circuitId', 'distance (km)']

# %%
cols = ['year', 'round', 'race', 'date', 'country', 'location', 'circuit', 'circuitRef', 'header', 'gap', 'distance (km)', 'lat', 'lng', 'raceId', 'circuitId']

race_info = race_info[cols]

race_info.head(50)
# Out:
#     year  round                       race        date        country  \
# 0   2023      1         Bahrain Grand Prix  2023-03-05        Bahrain
# 1   2023      2   Saudi Arabian Grand Prix  2023-03-19   Saudi Arabia
# 2   2023      3      Australian Grand Prix  2023-04-02      Australia
# 3   2023      4      Azerbaijan Grand Prix  2023-04-30     Azerbaijan
# 4   2023      5           Miami Grand Prix  2023-05-07            USA
# 5   2023      6          Monaco Grand Prix  2023-05-28         Monaco
# 6   2023      7         Spanish Grand Prix  2023-06-04          Spain
# 7   2023      8        Canadian Grand Prix  2023-06-18         Canada
# 8   2023      9        Austrian Grand Prix  2023-07-02        Austria
# 9   2023     10         British Grand Prix  2023-07-09             UK
# 10  2023     11       Hungarian Grand Prix  2023-07-23        Hungary
# 11  2023     12         Belgian Grand Prix  2023-07-30        Belgium
# ...

# %%
def header_dist(year, disp=False):
    df = race_info.loc[race_info['year'] == year]
    
    double_flag = triple_flag1 = triple_flag2 = False
    double_dist = triple_dist = 0
    
    for index, row in df.iterrows():
        if double_flag == True:
            double_dist = double_dist + row['distance (km)']
            if disp == True:
                print('Double', row['circuitRef'], row['distance (km)'])
            double_flag = False
            continue
            
        if triple_flag1 == True:
            triple_dist = triple_dist + row['distance (km)']
            if disp == True:
                print('Triple 1', row['circuitRef'], row['distance (km)'])
            triple_flag2 = True
            triple_flag1 = False
            continue
            
        if triple_flag2 == True:
            triple_dist = triple_dist + row['distance (km)']
            if disp == True:
                print('Triple 2', row['circuitRef'], row['distance (km)'])
            triple_flag1 = triple_flag2 = False
            continue
                 
        if row['header'] == 'double':
            double_flag = True  
            
        if row['header'] == 'triple':
            triple_flag1 = True
            
    double_dist = round(double_dist, 2)
    triple_dist = round(triple_dist, 2)
    if disp == True:
        print("\nDouble distance :", double_dist)
        print("Triple distance :", triple_dist)
        
    return double_dist, triple_dist

# %%
header_dist(2023)
# Out:
# (32831.71, 8632.85)

# %%
display_season(2023)
# Out:
#     year  round                      race        date        country  \
# 0   2023      1        Bahrain Grand Prix  2023-03-05        Bahrain
# 1   2023      2  Saudi Arabian Grand Prix  2023-03-19   Saudi Arabia
# 2   2023      3     Australian Grand Prix  2023-04-02      Australia
# 3   2023      4     Azerbaijan Grand Prix  2023-04-30     Azerbaijan
# 4   2023      5          Miami Grand Prix  2023-05-07            USA
# 5   2023      6         Monaco Grand Prix  2023-05-28         Monaco
# 6   2023      7        Spanish Grand Prix  2023-06-04          Spain
# 7   2023      8       Canadian Grand Prix  2023-06-18         Canada
# 8   2023      9       Austrian Grand Prix  2023-07-02        Austria
# 9   2023     10        British Grand Prix  2023-07-09             UK
# 10  2023     11      Hungarian Grand Prix  2023-07-23        Hungary
# 11  2023     12        Belgian Grand Prix  2023-07-30        Belgium
# 12  2023     13          Dutch Grand Prix  2023-08-27    Netherlands
# ...

# %%
header_dist(2022)
# Out:
# (31469.55, 1066.89)

# %%
display_season(2022)
# Out:
#     year  round                       race        date       country  \
# 22  2022      1         Bahrain Grand Prix  2022-03-20       Bahrain
# 23  2022      2   Saudi Arabian Grand Prix  2022-03-27  Saudi Arabia
# 24  2022      3      Australian Grand Prix  2022-04-10     Australia
# 25  2022      4  Emilia Romagna Grand Prix  2022-04-24         Italy
# 26  2022      5           Miami Grand Prix  2022-05-08           USA
# 27  2022      6         Spanish Grand Prix  2022-05-22         Spain
# 28  2022      7          Monaco Grand Prix  2022-05-29        Monaco
# 29  2022      8      Azerbaijan Grand Prix  2022-06-12    Azerbaijan
# 30  2022      9        Canadian Grand Prix  2022-06-19        Canada
# 31  2022     10         British Grand Prix  2022-07-03            UK
# 32  2022     11        Austrian Grand Prix  2022-07-10       Austria
# 33  2022     12          French Grand Prix  2022-07-24        France
# 34  2022     13       Hungarian Grand Prix  2022-07-31       Hungary
# ...

# %%
dist_calc(2023)
# Out:
# (131513.24, 22)

# %%
header_count(2023)
# Out:
# (5, 7, 1)

# %%
header_dist(2023)
# Out:
# (32831.71, 8632.85)

# %%
cols = ['year', 'rounds', 'tot dist (km)', 'single', 'double', 'triple', 'tot double dist (km)', 'avg double dist (km)', 'tot triple dist (km)', 'avg triple dist (km)']
row = dict.fromkeys(cols, 0)

season_info = pd.DataFrame(columns = cols)

for year in range(1950, 2024):
    total_dist, rounds = dist_calc(year)
    single, double, triple = header_count(year)
    double_dist, triple_dist = header_dist(year)
    
    if double>0:
        avg_double_dist = round(double_dist/double, 2)
    else:
        avg_double_dist = 0
    if triple>0:
        avg_triple_dist = round(triple_dist/triple, 2)
    else:
        avg_triple_dist = 0
        
    row['year'] = year
    row['rounds'] = rounds
    row['tot dist (km)'] = total_dist
    row['single'] = single
    row['double'] = double
    row['triple'] = triple
    row['tot double dist (km)'] = double_dist
    row['avg double dist (km)'] = avg_double_dist
    row['tot triple dist (km)'] = triple_dist
    row['avg triple dist (km)'] = avg_triple_dist
    
    #print(row)
    
    season = pd.DataFrame([row])
    
    season_info = pd.concat([season_info, season], ignore_index=True)
        
    
    
    """
    print("\nYear :", year)
    print("No. of rounds :", rounds)
    print("Total distance :", total_dist, "kms")
    print("Single headers :", single)
    print("Double headers :", double)
    print("Triple headers :", triple)
    print("Total double header distance : ", double_dist, "kms")
    print("Total triple header distance : ", triple_dist, "kms")
    print("Average double header distance : ", avg_double_dist, "kms")
    print("Average triple header distance : ", avg_triple_dist, "kms")
    """

# %%
season_info.tail(20)
# Out:
#     year rounds  tot dist (km) single double triple  tot double dist (km)  \
# 54  2004     18       65336.52     12      3      0               2604.17
# 55  2005     19       67786.44      7      6      0               5482.48
# 56  2006     18       78453.33      8      5      0              10584.32
# 57  2007     17       67030.16      7      5      0              10201.77
# 58  2008     18       74634.27     12      3      0               8626.34
# 59  2009     17       77986.32      9      4      0              19491.87
# 60  2010     19       99435.61     11      4      0              19780.02
# 61  2011     19       72617.53     11      4      0               6134.92
# 62  2012     20       83156.06      6      7      0              25869.62
# 63  2013     19       81314.61      7      6      0              25056.47
# 64  2014     19      100573.62     11      4      0              22840.41
# 65  2015     19       93769.32     13      3      0              13042.68
# ...

# %%
datapath = "f1db_csv/"

# %%
race_info.to_csv("Race_Info.csv", index=False)

# %%
season_info.to_csv("Season_Info.csv", index=False)

# %%
history_30 = race_info.loc[race_info['year'] >= 1993, 'circuitRef'].unique().tolist()

print(history_30)
# Out:
# ['bahrain', 'jeddah', 'albert_park', 'baku', 'miami', 'monaco', 'catalunya', 'villeneuve', 'red_bull_ring', 'silverstone', 'hungaroring', 'spa', 'zandvoort', 'monza', 'marina_bay', 'suzuka', 'losail', 'americas', 'rodriguez', 'interlagos', 'vegas', 'yas_marina', 'imola', 'ricard', 'portimao', 'sochi', 'istanbul', 'mugello', 'nurburgring', 'shanghai', 'hockenheimring', 'sepang', 'yeongam', 'buddh', 'valencia', 'magny_cours', 'fuji', 'indianapolis', 'galvez', 'jerez', 'estoril', 'okayama', 'adelaide', 'kyalami', 'donington']

# %%
len(history_30)
# Out:
# 45

# %%
circuits.shape
# Out:
# (77, 7)

# %%
circuits.loc[circuits['circuitRef'].isin(history_30)]
# Out:
#     circuitId      circuitRef                                  name  \
# 0           1     albert_park        Albert Park Grand Prix Circuit
# 1           2          sepang          Sepang International Circuit
# 2           3         bahrain         Bahrain International Circuit
# 3           4       catalunya        Circuit de Barcelona-Catalunya
# 4           5        istanbul                         Istanbul Park
# 5           6          monaco                     Circuit de Monaco
# 6           7      villeneuve             Circuit Gilles Villeneuve
# 7           8     magny_cours         Circuit de Nevers Magny-Cours
# 8           9     silverstone                   Silverstone Circuit
# 9          10  hockenheimring                        Hockenheimring
# 10         11     hungaroring                           Hungaroring
# 11         12        valencia               Valencia Street Circuit
# 12         13             spa          Circuit de Spa-Francorchamps
# ...
